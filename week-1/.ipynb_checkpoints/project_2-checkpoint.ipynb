# %% [markdown]
# ![image.png](attachment:c4a94661-0c9e-42f9-93fe-e7330d293596.png)

# %% [markdown]
# print("COMPUND INTEREST CALCULATOR")
#
# # declare variables and get input from the user
#
# p = float(input("Enter the principal amount>>> "))
# r = float(input("Enter the annual interest rate>>> "))
# n = float(input("Enter the number of times the interest is compounded per year>>> "))
# t = float(input("Enter the number of years>>> "))
#
# # calculate the compound interest
# a = p *(1 + r / n) ** (n * t)
#
# # print the output
# print(f"The compound interest is {a:.2f}")
