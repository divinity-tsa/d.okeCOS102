# %% [markdown]
# ![image.png](attachment:83b89d81-8ee9-43d0-ae6f-fd90c608dd9e.png)

# %%
print("SIMPLE INTEREST CALCULATOR")

# Get input from user
p = float(input("Enter the principal amount: "))
r = float(input("Enter the rate of interest: "))
t = float(input("Enter the time in years: "))

# Calculate for simple interest
a = p * (1 + (r / 100) * t)

# Print the output
print(f"The simple interest is: {a:.2f}")
# Out:
# SIMPLE INTEREST CALCULATOR
# Enter the principal amount:  3400
# Enter the rate of interest:  24
# Enter the time in years:  2.33
# The simple interest is: 5301.28
