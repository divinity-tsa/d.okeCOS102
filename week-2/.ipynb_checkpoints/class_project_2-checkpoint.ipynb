# %%
import numpy as np

print("Choose the equation for which you would like to calculate the roots>>>")
print("1. Quadratic equation")
print("2. Cubic equation")
print("3. Quartic equation")


choice = int(input("Enter your choice (1, 2, or 3):"))

if choice == 1:
    a = float(input("Enter a: "))
    b = float(input("Enter b: "))
    c = float(input("Enter c: "))

    roots = np.roots([a, b, c])
    print(f"The roots are: {roots}")


elif choice == 2:
    a= float(input("Enter a: "))
    b = float(input("Enter b: "))
    c = float(input("Enter c: "))
    d = float(input("Enter d: "))

    roots = np.roots([a, b, c, d])
    print(f"The roots are: {roots}")


elif choice == 3:
    a = float(input("Enter a: "))
    b = float(input("Enter b: "))
    c = float(input("Enter c: "))
    d = float(input("Enter d: "))
    e = float(input("Enter e: "))



    roots = np.roots([a, b, c, d, e])
    print(f"The roots are: {roots}")

else:
    print("Invalid choice. Please try again.")
# Out:
# Choose the equation for which you would like to calculate the roots>>>
# 1. Quadratic equation
# 2. Cubic equation
# 3. Quartic equation
# Enter your choice (1, 2, or 3): 1
# Enter a:  3
# Enter b:  2
# Enter c:  1
# The roots are: [-0.33333333+0.47140452j -0.33333333-0.47140452j]
