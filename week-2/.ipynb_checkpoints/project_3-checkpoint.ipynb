# %%
import pandas as pd

girls = {
    "Name": ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"],
    "Age" : [17,16,17,18,16,18,17,20,19,17],
    "Height" : [5.5,6.0,5.4,5.9,5.6,5.5,6.0,5.7,5.5,5.0],
    "Score" : [74,87,75,68,66,78,87,98,54,60]
}


boys = {
    "Name": ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"],
    "Age" : [17,16,17,18,16,18,17,20,19,17],
    "Height" : [5.5,6.0,5.4,5.9,5.6,5.5,6.0,5.7,5.5,5.0],
    "Score" : [74,87,75,68,66,78,87,98,54,60]
}


df_girls = pd.DataFrame(girls)
df_boys = pd.DataFrame(boys)

df_class = pd.concat([df_girls, df_boys], ignore_index = True)

print(df_class)
# Out:
#        Name  Age  Height  Score
# 0    Evelyn   17     5.5     74
# 1   Jessica   16     6.0     87
# 2     Somto   17     5.4     75
# 3     Edith   18     5.9     68
# 4      Liza   16     5.6     66
# 5   Madonna   18     5.5     78
# 6      Waje   17     6.0     87
# 7      Tola   20     5.7     98
# 8     Aisha   19     5.5     54
# 9    Latifa   17     5.0     60
# 10  Chinedu   17     5.5     74
# 11     Liam   16     6.0     87
# 12     Wale   17     5.4     75
# 13   Gbenga   18     5.9     68
# 14   Abiola   16     5.6     66
# 15     Kola   18     5.5     78
# 16    Kunle   17     6.0     87
# 17   George   20     5.7     98
# 18   Thomas   19     5.5     54
# 19   Wesley   17     5.0     60
