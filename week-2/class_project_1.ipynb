# %%
START
INPUT Prices
INPUT Quantity
COMPUTE Total = Price * Quantity

INPUT Payment
IF Payment >= Total THEN
COMPUTE Change = Payment - Total
PRINT Change
PRINT Total


ELSE 
PRINT "Insufficient payment. Kindly complete payment"


END

# %% [markdown]
# ![flowchart for project 1a](project_1a_flowchart.png)
